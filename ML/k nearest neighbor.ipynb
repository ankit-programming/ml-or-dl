# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
x = data[["Open","High","vol","Low"]]
y = data["Close"]

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.05)

# %% [raw]
# from sklearn.neighbors import KNeighborsRegressor
#
# knn = KNeighborsRegressor(n_neighbors=10)
# knn.fit(X_train,y_train)
# knnpre = knn.predict(X_test)

# %%
knn.score(X_test,y_test)
# Out:
# 0.40790058304853105

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

knnmse = mean_squared_error(y_test,knnpre)
knnrms = np.sqrt(knnmse)

# %%
knnrms
# Out:
# 769.724679585175

# %%
#VISUALIZATIOJ
import matplotlib.pyplot as plt
plt.figure(figsize = (16,10))
plt.subplot(2,3,1)
plt.plot([16600,16800,17000,17200,17400,17500,17600,17700],y_test,"k*--",label = "actual")
plt.plot([16600,16800,17000,17200,17400,17500,17600,17700],knnpre,color = "g",label = "LR")
plt.legend()

# %%
#         VERY VERY BAD
